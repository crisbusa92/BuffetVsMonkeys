# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
#path_to_market_data = '../Escritorio/SP500_HISTORY.csv'
path_to_market_data = 'C:/Users/JERRY/Documents/DATA ANALYTICS/Proyecto/VERSION 04_08_2020/BuffetVsMonkeys-branchC/'
   
sp500_df = pd.read_csv(path_to_market_data + '^GSPC.csv')
sp500_df['Date']= pd.to_datetime(sp500_df['Date'])
sp500_df = sp500_df.sort_values('Date', ascending=True)
sp500_df.head()
#pd.date_range(start = pd.Timestamp('1927-12-30'),end = pd.Timestamp('2020-08-03'),freq='1D')
#sp500_df['Adj Close'] = np.random.random_sample((len(sp500_df)))
#years = sorted(np.unique(sp500_df['Date'].dt.year))

#sp500_df(head)
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume
# 0 1927-12-30  17.660000  17.660000  17.660000  17.660000  17.660000       0
# 1 1928-01-03  17.760000  17.760000  17.760000  17.760000  17.760000       0
# 2 1928-01-04  17.719999  17.719999  17.719999  17.719999  17.719999       0
# 3 1928-01-05  17.549999  17.549999  17.549999  17.549999  17.549999       0
# 4 1928-01-06  17.660000  17.660000  17.660000  17.660000  17.660000       0

# %%
fig, ax = plt.subplots(figsize=(16, 8))
plt.plot(sp500_df['Date'], sp500_df['Adj Close'], color= 'blue')
plt.title('S&P 500')
plt.grid()
plt.show()

# %%
#sp500_df.head()
sp500_df
# Out:
#              Date         Open         High          Low        Close  \
# 0      30/12/1927    17.660000    17.660000    17.660000    17.660000
# 1      03/01/1928    17.760000    17.760000    17.760000    17.760000
# 2      04/01/1928    17.719999    17.719999    17.719999    17.719999
# 3      05/01/1928    17.549999    17.549999    17.549999    17.549999
# 4      06/01/1928    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23252  28/07/2020  3234.270020  3243.719971  3216.169922  3218.439941
# 23253  29/07/2020  3227.219971  3264.739990  3227.219971  3258.439941
# 23254  30/07/2020  3231.760010  3250.919922  3204.129883  3246.219971
# 23255  31/07/2020  3270.449951  3272.169922  3220.260010  3271.120117
# 23256  03/08/2020  3288.260010  3302.729980  3284.530029  3294.610107
#
#          Adj Close      Volume
# 0        17.660000           0
# 1        17.760000           0
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 8))
plt.plot(sp500_df['Date'], sp500_df['Adj Close'], linewidth=3, color='blue')
plt.title('S&P 500')
plt.legend(loc= 'upper left')
plt.grid()
#Get second axis
ax2 = ax.twinx()
#Price vs. Shares
plt.plot(sp500_df['Date'],
         sp500_df['Volume'], label='Volume', color='red')
ax2.legend(loc='lower right', frameon= False)
# Out:
# No handles with labels found to put in legend.

# %%
#Creating subsets
sp500_df_tmp = sp500_df[sp500_df['Date'] > '01-01-2006']
fig, ax = plt.subplots(figsize=(16, 8))
plt.plot(sp500_df_tmp['Date'], sp500_df_tmp['Adj Close'], linewidth=3, color='blue')
plt.title('S&P 500')
plt.legend(loc= 'upper left')
plt.grid()

#Getting second axis
ax2 = ax.twinx()
plt.plot(sp500_df_tmp['Date'],
         sp500_df_tmp['Volume'].rolling(window=50).mean().values, label='Volume', color='red')

#plt.plot(sp500_df_tmp['Date'],
#         sp500_df_tmp['Volume'], label='Volume', color='red')
ax2.legend(loc= 'lower right',frameon=False)

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
grouper.plot()
RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
grouper = df.groupby(['Date', pd.Grouper(key='Date', freq='Y')])


plt.plot(sp500_df.'Date', sp500_df.'Open','r.-')
grouper = df.groupby(['Date', pd.Grouper(key='Date', freq='Y')])
plt.ylabel('Algo en Y')
plt.xticks(sp500_df.Year[::3].Tolist()+2011)
plot.show()
# Out:
#   File "<ipython-input-50-e74df6e47d3f>", line 1
#     plt.plot(sp500_df.'Date', sp500_df.'Open','r.-')
#                            ^
# SyntaxError: invalid syntax
